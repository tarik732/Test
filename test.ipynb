# %% [markdown]
# <a href="https://colab.research.google.com/github/tarik732/Test/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(9)
# Out:
# 9
